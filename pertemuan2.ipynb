# %% [markdown]
# <a href="https://colab.research.google.com/github/fernandayusafitri/Pemerograman-Dasar/blob/main/pertemuan2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#latihan1
tegangan_panel = 18
arus_panel = 6
jenis_sel = "Monocrystalline"

print(tegangan_panel)
print(arus_panel)
print(jenis_sel)

#latihan2
komponen = "Transistor"
tegangan = 18
resistensi = 4.7
aktif = True

print(komponen, type(komponen))
print(tegangan, type(tegangan))
print(resistensi, type(resistensi))
print(aktif, type(aktif))

#latihan3
nama_unit = "PLTS Nunukan" #str
jumlah_panel = 240         #int
tegangan_keluaran = 48.5   #float
sedang_beroperasi = True   #bool

print(nama_unit, type(nama_unit))
print(jumlah_panel, type(jumlah_panel))
print(tegangan_keluaran, type(tegangan_keluaran))
print(sedang_beroperasi, type(sedang_beroperasi))

#latihan4
tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]
print("Pertama:", tegangan_harian[0])
print("Terakhir:", tegangan_harian[5])
tegangan_harian.append(222.0)
print("Jumlah data:", len(tegangan_harian))

#latihan5
motor_listrik = {"nama":"polytron", "daya_kW":3.2, "tegangan_V":72, "rpm":4500}
print(motor_listrik["tegangan_V"])
motor_listrik["rpm"] = 3000
print(motor_listrik)

#latihan6
# Jawaban Latihan 6
pembangkit = [
    {"nama": "Unit-1", "kapasitas_MW": 100, "status": "operasi"},
    {"nama": "Unit-2", "kapasitas_MW": 150, "status": "operasi"},
    {"nama": "Unit-3", "kapasitas_MW": 80,  "status": "pemeliharaan"},
]
print("Nama unit kedua:", pembangkit[1]["nama"])
pembangkit[0]["status"] = "pemeliharaan"
print("Status Unit-1:", pembangkit[0]["status"])
pembangkit.append({"nama": "Unit-4", "kapasitas_MW": 110, "status": "pemeliharaan"})
print(pembangkit)
# Out:
# 18
# 6
# Monocrystalline
# Transistor <class 'str'>
# 18 <class 'int'>
# 4.7 <class 'float'>
# True <class 'bool'>
# PLTS Nunukan <class 'str'>
# 240 <class 'int'>
# 48.5 <class 'float'>
# True <class 'bool'>
# Pertama: 217.5
# Terakhir: 216.9
# Jumlah data: 7
# 72
# {'nama': 'polytron', 'daya_kW': 3.2, 'tegangan_V': 72, 'rpm': 3000}
# Nama unit kedua: Unit-2
# Status Unit-1: pemeliharaan
# [{'nama': 'Unit-1', 'kapasitas_MW': 100, 'status': 'pemeliharaan'}, {'nama': 'Unit-2', 'kapasitas_MW': 150, 'status': 'operasi'}, {'nama': 'Unit-3', 'kapasitas_MW': 80, 'status': 'pemeliharaan'}, {'nama': 'Unit-4', 'kapasitas_MW': 110, 'status': 'pemeliharaan'}]
