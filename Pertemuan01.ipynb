# %% [markdown]
# <a href="https://colab.research.google.com/github/fernandayusafitri/Pemerograman-Dasar/blob/main/Pertemuan01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata Saya
nama = "fernanda ayu"
umur = 20
jurusan = "Elektro"
prodi = "RPE"
semester = 3
matakuliah = "Pemerograman Dasar"
status_lulus = False

print (nama)
print (umur)
print (jurusan)
print (prodi)
print (semester)
print (matakuliah)
print (status_lulus)
# Out:
# fernanda ayu
# 20
# Elektro
# RPE
# 3
# Pemerograman Dasar
# False
